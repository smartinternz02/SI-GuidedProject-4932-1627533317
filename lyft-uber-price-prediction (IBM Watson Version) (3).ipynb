# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from scipy import stats
import joblib

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

if os.environ.get('RUNTIME_ENV_LOCATION_TYPE') == 'external':
    endpoint_368e284b0b2147a285243b60b6fdb7c5 = 'https://s3.us.cloud-object-storage.appdomain.cloud'
else:
    endpoint_368e284b0b2147a285243b60b6fdb7c5 = 'https://s3.private.us.cloud-object-storage.appdomain.cloud'

client_368e284b0b2147a285243b60b6fdb7c5 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='CxMr6bNPS44SQM1s7y9BCTkNwgR-QG347m412edvRP0U',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url=endpoint_368e284b0b2147a285243b60b6fdb7c5)

body = client_368e284b0b2147a285243b60b6fdb7c5.get_object(Bucket='modeldeployement-donotdelete-pr-amwt1tedsf4wfh',Key='cab_rides.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

data = pd.read_csv(body)
data.head()
# Out:
#    distance cab_type     time_stamp    destination            source  price  \
# 0      0.44     Lyft  1544952607890  North Station  Haymarket Square    5.0
# 1      0.44     Lyft  1543284023677  North Station  Haymarket Square   11.0
# 2      0.44     Lyft  1543366822198  North Station  Haymarket Square    7.0
# 3      0.44     Lyft  1543553582749  North Station  Haymarket Square   26.0
# 4      0.44     Lyft  1543463360223  North Station  Haymarket Square    9.0
#
#    surge_multiplier                                    id    product_id  \
# 0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7     lyft_line
# 1               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d  lyft_premier
# 2               1.0  981a3613-77af-4620-a42a-0c0866077d1e          lyft
# 3               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512   lyft_luxsuv
# 4               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a     lyft_plus
#
#            name
# 0        Shared
# 1           Lux
# 2          Lyft
# 3  Lux Black XL
# 4       Lyft XL

# %%
body = client_368e284b0b2147a285243b60b6fdb7c5.get_object(Bucket='modeldeployement-donotdelete-pr-amwt1tedsf4wfh',Key='weather.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

weather = pd.read_csv(body)
weather.head()
# Out:
#     temp            location  clouds  pressure    rain  time_stamp  humidity  \
# 0  42.42            Back Bay     1.0   1012.14  0.1228  1545003901      0.77
# 1  42.43         Beacon Hill     1.0   1012.15  0.1846  1545003901      0.76
# 2  42.50   Boston University     1.0   1012.15  0.1089  1545003901      0.76
# 3  42.11              Fenway     1.0   1012.13  0.0969  1545003901      0.77
# 4  43.13  Financial District     1.0   1012.14  0.1786  1545003901      0.75
#
#     wind
# 0  11.25
# 1  11.32
# 2  11.07
# 3  11.09
# 4  11.49

# %%
#data = pd.read_csv('cab_rides.csv')
#weather = pd.read_csv('weather.csv')

# %%
data.head()
# Out:
#    distance cab_type     time_stamp    destination            source  price  \
# 0      0.44     Lyft  1544952607890  North Station  Haymarket Square    5.0
# 1      0.44     Lyft  1543284023677  North Station  Haymarket Square   11.0
# 2      0.44     Lyft  1543366822198  North Station  Haymarket Square    7.0
# 3      0.44     Lyft  1543553582749  North Station  Haymarket Square   26.0
# 4      0.44     Lyft  1543463360223  North Station  Haymarket Square    9.0
#
#    surge_multiplier                                    id    product_id  \
# 0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7     lyft_line
# 1               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d  lyft_premier
# 2               1.0  981a3613-77af-4620-a42a-0c0866077d1e          lyft
# 3               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512   lyft_luxsuv
# 4               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a     lyft_plus
#
#            name
# 0        Shared
# 1           Lux
# 2          Lyft
# 3  Lux Black XL
# 4       Lyft XL

# %%
weather.head()
# Out:
#     temp            location  clouds  pressure    rain  time_stamp  humidity  \
# 0  42.42            Back Bay     1.0   1012.14  0.1228  1545003901      0.77
# 1  42.43         Beacon Hill     1.0   1012.15  0.1846  1545003901      0.76
# 2  42.50   Boston University     1.0   1012.15  0.1089  1545003901      0.76
# 3  42.11              Fenway     1.0   1012.13  0.0969  1545003901      0.77
# 4  43.13  Financial District     1.0   1012.14  0.1786  1545003901      0.75
#
#     wind
# 0  11.25
# 1  11.32
# 2  11.07
# 3  11.09
# 4  11.49

# %% [markdown]
# # Data Preprocessing

# %%
data['date'] = pd.to_datetime(data['time_stamp']/1000, unit='s')
weather['date'] = pd.to_datetime(weather['time_stamp'], unit='s')

# %%
data.head()
# Out:
#    distance cab_type     time_stamp    destination            source  price  \
# 0      0.44     Lyft  1544952607890  North Station  Haymarket Square    5.0
# 1      0.44     Lyft  1543284023677  North Station  Haymarket Square   11.0
# 2      0.44     Lyft  1543366822198  North Station  Haymarket Square    7.0
# 3      0.44     Lyft  1543553582749  North Station  Haymarket Square   26.0
# 4      0.44     Lyft  1543463360223  North Station  Haymarket Square    9.0
#
#    surge_multiplier                                    id    product_id  \
# 0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7     lyft_line
# 1               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d  lyft_premier
# 2               1.0  981a3613-77af-4620-a42a-0c0866077d1e          lyft
# 3               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512   lyft_luxsuv
# 4               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a     lyft_plus
#
#            name                          date
# 0        Shared 2018-12-16 09:30:07.890000105
# 1           Lux 2018-11-27 02:00:23.677000046
# 2          Lyft 2018-11-28 01:00:22.197999954
# 3  Lux Black XL 2018-11-30 04:53:02.749000072
# 4       Lyft XL 2018-11-29 03:49:20.223000050

# %%
weather.head()
# Out:
#     temp            location  clouds  pressure    rain  time_stamp  humidity  \
# 0  42.42            Back Bay     1.0   1012.14  0.1228  1545003901      0.77
# 1  42.43         Beacon Hill     1.0   1012.15  0.1846  1545003901      0.76
# 2  42.50   Boston University     1.0   1012.15  0.1089  1545003901      0.76
# 3  42.11              Fenway     1.0   1012.13  0.0969  1545003901      0.77
# 4  43.13  Financial District     1.0   1012.14  0.1786  1545003901      0.75
#
#     wind                date
# 0  11.25 2018-12-16 23:45:01
# 1  11.32 2018-12-16 23:45:01
# 2  11.07 2018-12-16 23:45:01
# 3  11.09 2018-12-16 23:45:01
# 4  11.49 2018-12-16 23:45:01

# %%
weather.drop(['pressure', 'humidity', 'wind'], axis=1, inplace=True)

# %%
data['merged'] = data['source'].astype('str') + ' ' + data['date'].dt.strftime('%Y-%m-%d').astype('str') + ' ' + data['date'].dt.strftime('%H:%M:%S').astype('str')
data['dest_merged'] = data['destination'].astype('str') + ' ' + data['date'].dt.strftime('%Y-%m-%d').astype('str') + ' ' + data['date'].dt.strftime('%H:%M:%S').astype('str')
weather['merged'] = weather['location'].astype('str') + ' ' + weather['date'].dt.strftime('%Y-%m-%d').astype('str') + ' ' + weather['date'].dt.strftime('%H:%M:%S').astype('str')

# %%
#Dropping the unrequired columns 
data.drop(['product_id','time_stamp','date'], axis=1, inplace=True)
weather.drop(['time_stamp','date'], axis=1, inplace=True)

# %%
data.head()
# Out:
#    distance cab_type    destination            source  price  \
# 0      0.44     Lyft  North Station  Haymarket Square    5.0
# 1      0.44     Lyft  North Station  Haymarket Square   11.0
# 2      0.44     Lyft  North Station  Haymarket Square    7.0
# 3      0.44     Lyft  North Station  Haymarket Square   26.0
# 4      0.44     Lyft  North Station  Haymarket Square    9.0
#
#    surge_multiplier                                    id          name  \
# 0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7        Shared
# 1               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d           Lux
# 2               1.0  981a3613-77af-4620-a42a-0c0866077d1e          Lyft
# 3               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512  Lux Black XL
# 4               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a       Lyft XL
#
#                                  merged                        dest_merged
# 0  Haymarket Square 2018-12-16 09:30:07  North Station 2018-12-16 09:30:07
# 1  Haymarket Square 2018-11-27 02:00:23  North Station 2018-11-27 02:00:23
# 2  Haymarket Square 2018-11-28 01:00:22  North Station 2018-11-28 01:00:22
# 3  Haymarket Square 2018-11-30 04:53:02  North Station 2018-11-30 04:53:02
# 4  Haymarket Square 2018-11-29 03:49:20  North Station 2018-11-29 03:49:20

# %%
weather.head()
# Out:
#     temp            location  clouds    rain  \
# 0  42.42            Back Bay     1.0  0.1228
# 1  42.43         Beacon Hill     1.0  0.1846
# 2  42.50   Boston University     1.0  0.1089
# 3  42.11              Fenway     1.0  0.0969
# 4  43.13  Financial District     1.0  0.1786
#
#                                    merged
# 0            Back Bay 2018-12-16 23:45:01
# 1         Beacon Hill 2018-12-16 23:45:01
# 2   Boston University 2018-12-16 23:45:01
# 3              Fenway 2018-12-16 23:45:01
# 4  Financial District 2018-12-16 23:45:01

# %%
merged_data = pd.merge(data,weather, how='inner', on='merged')
merged_data
# Out:
#       distance cab_type              destination            source  price  \
# 0         0.55     Uber            South Station  Theatre District    7.0
# 1         1.57     Uber                North End  Theatre District   18.0
# 2         2.12     Lyft  Northeastern University  Theatre District   10.5
# 3         2.12     Lyft  Northeastern University  Theatre District    7.0
# 4         2.12     Lyft  Northeastern University  Theatre District   16.5
# ...        ...      ...                      ...               ...    ...
# 3861      0.64     Lyft                 West End  Haymarket Square   27.5
# 3862      0.64     Lyft                 West End  Haymarket Square   16.5
# 3863      0.49     Uber            North Station  Haymarket Square    7.0
# 3864      0.49     Uber            North Station  Haymarket Square    7.0
# 3865      0.49     Uber            North Station  Haymarket Square    7.0
#
#       surge_multiplier                                    id          name  \
# 0                  1.0  74b72f4c-28bc-4640-a427-ec60b4b11f82         UberX
# 1                  1.0  e5aa2477-afb5-4b83-a69d-18ee7d2bfd1d         Black
# 2                  1.0  4d24470f-167a-4d1f-9cab-c123a0713491          Lyft
# 3                  1.0  7902bfaf-5987-499b-9c04-222f4182c581        Shared
# 4                  1.0  91129083-ed19-41fd-b16a-06c729ff0790       Lyft XL
# ...                ...                                   ...           ...
# 3861               1.0  06fb0785-132d-4d59-a147-00655bc1b8f9  Lux Black XL
# 3862               1.0  2be8dbc1-2a40-43e4-9e69-691420768750     Lux Black
# 3863               1.0  9a79355e-26e1-4f81-936e-9fa3aa06f509      UberPool
# 3864               1.0  f92fafbf-d78b-410b-a957-f15af2022518         UberX
# 3865               1.0  fe3e9738-3d72-4e23-a478-5938dbffbadd           WAV
#
#                                     merged  \
# 0     Theatre District 2018-11-28 17:32:07
# 1     Theatre District 2018-11-28 17:32:07
# 2     Theatre District 2018-11-28 17:32:07
# 3     Theatre District 2018-11-28 17:32:07
# 4     Theatre District 2018-11-28 17:32:07
# ...                                    ...
# 3861  Haymarket Square 2018-11-26 06:29:03
# 3862  Haymarket Square 2018-11-26 06:29:03
# 3863  Haymarket Square 2018-11-28 10:06:24
# 3864  Haymarket Square 2018-11-28 10:06:24
# 3865  Haymarket Square 2018-11-28 10:06:24
#
#                                       dest_merged   temp          location  \
# 0               South Station 2018-11-28 17:32:07  41.47  Theatre District
# 1                   North End 2018-11-28 17:32:07  41.47  Theatre District
# 2     Northeastern University 2018-11-28 17:32:07  41.47  Theatre District
# 3     Northeastern University 2018-11-28 17:32:07  41.47  Theatre District
# 4     Northeastern University 2018-11-28 17:32:07  41.47  Theatre District
# ...                                           ...    ...               ...
# 3861                 West End 2018-11-26 06:29:03  40.60  Haymarket Square
# 3862                 West End 2018-11-26 06:29:03  40.60  Haymarket Square
# 3863            North Station 2018-11-28 10:06:24  33.18  Haymarket Square
# 3864            North Station 2018-11-28 10:06:24  33.18  Haymarket Square
# 3865            North Station 2018-11-28 10:06:24  33.18  Haymarket Square
#
#       clouds  rain
# 0       0.85   NaN
# 1       0.85   NaN
# 2       0.85   NaN
# 3       0.85   NaN
# 4       0.85   NaN
# ...      ...   ...
# 3861    1.00   NaN
# 3862    1.00   NaN
# 3863    0.14   NaN
# 3864    0.14   NaN
# 3865    0.14   NaN
#
# [3866 rows x 14 columns]

# %%
merged_data.head()
# Out:
#    distance cab_type              destination            source  price  \
# 0      0.55     Uber            South Station  Theatre District    7.0
# 1      1.57     Uber                North End  Theatre District   18.0
# 2      2.12     Lyft  Northeastern University  Theatre District   10.5
# 3      2.12     Lyft  Northeastern University  Theatre District    7.0
# 4      2.12     Lyft  Northeastern University  Theatre District   16.5
#
#    surge_multiplier                                    id     name  \
# 0               1.0  74b72f4c-28bc-4640-a427-ec60b4b11f82    UberX
# 1               1.0  e5aa2477-afb5-4b83-a69d-18ee7d2bfd1d    Black
# 2               1.0  4d24470f-167a-4d1f-9cab-c123a0713491     Lyft
# 3               1.0  7902bfaf-5987-499b-9c04-222f4182c581   Shared
# 4               1.0  91129083-ed19-41fd-b16a-06c729ff0790  Lyft XL
#
#                                  merged  \
# 0  Theatre District 2018-11-28 17:32:07
# 1  Theatre District 2018-11-28 17:32:07
# 2  Theatre District 2018-11-28 17:32:07
# 3  Theatre District 2018-11-28 17:32:07
# 4  Theatre District 2018-11-28 17:32:07
#
#                                    dest_merged   temp          location  \
# 0            South Station 2018-11-28 17:32:07  41.47  Theatre District
# 1                North End 2018-11-28 17:32:07  41.47  Theatre District
# 2  Northeastern University 2018-11-28 17:32:07  41.47  Theatre District
# 3  Northeastern University 2018-11-28 17:32:07  41.47  Theatre District
# 4  Northeastern University 2018-11-28 17:32:07  41.47  Theatre District
#
#    clouds  rain
# 0    0.85   NaN
# 1    0.85   NaN
# 2    0.85   NaN
# 3    0.85   NaN
# 4    0.85   NaN

# %%
merged_data2 = pd.merge(merged_data,weather, how='inner', left_on='dest_merged', right_on='merged')
merged_data2
# Out:
#       distance cab_type       destination              source  price  \
# 0         0.55     Uber     South Station    Theatre District    7.0
# 1         1.57     Uber         North End    Theatre District   18.0
# 2         1.75     Lyft         North End         Beacon Hill   26.0
# 3         2.21     Uber         North End         Beacon Hill   18.5
# 4         2.21     Uber         North End         Beacon Hill    8.5
# ...        ...      ...               ...                 ...    ...
# 2614      1.18     Lyft  Haymarket Square  Financial District   13.5
# 2615      1.18     Lyft  Haymarket Square  Financial District   27.5
# 2616      1.18     Lyft  Haymarket Square  Financial District   10.5
# 2617      0.64     Lyft          West End    Haymarket Square   27.5
# 2618      0.64     Lyft          West End    Haymarket Square   16.5
#
#       surge_multiplier                                    id          name  \
# 0                  1.0  74b72f4c-28bc-4640-a427-ec60b4b11f82         UberX
# 1                  1.0  e5aa2477-afb5-4b83-a69d-18ee7d2bfd1d         Black
# 2                  1.0  75924e6f-60ac-46c2-aa92-f93a61eca726  Lux Black XL
# 3                  1.0  064ac617-a425-43b0-9dbe-91e244c0af65         Black
# 4                  1.0  1bbd3878-eb88-46f9-badf-77a0090dcddb         UberX
# ...                ...                                   ...           ...
# 2614               1.0  614ab356-c34c-417b-95ec-82a965c4341f           Lux
# 2615               1.0  7ce3b196-f348-4d2d-8b57-20753ff7aacd  Lux Black XL
# 2616               1.0  906eeba2-d494-4fba-9f82-aad1b9f820bd       Lyft XL
# 2617               1.0  06fb0785-132d-4d59-a147-00655bc1b8f9  Lux Black XL
# 2618               1.0  2be8dbc1-2a40-43e4-9e69-691420768750     Lux Black
#
#                                     merged_x  \
# 0       Theatre District 2018-11-28 17:32:07
# 1       Theatre District 2018-11-28 17:32:07
# 2            Beacon Hill 2018-11-28 17:32:07
# 3            Beacon Hill 2018-11-28 17:32:07
# 4            Beacon Hill 2018-11-28 17:32:07
# ...                                      ...
# 2614  Financial District 2018-11-26 06:29:03
# 2615  Financial District 2018-11-26 06:29:03
# 2616  Financial District 2018-11-26 06:29:03
# 2617    Haymarket Square 2018-11-26 06:29:03
# 2618    Haymarket Square 2018-11-26 06:29:03
#
#                                dest_merged  temp_x          location_x  \
# 0        South Station 2018-11-28 17:32:07   41.47    Theatre District
# 1            North End 2018-11-28 17:32:07   41.47    Theatre District
# 2            North End 2018-11-28 17:32:07   41.30         Beacon Hill
# 3            North End 2018-11-28 17:32:07   41.30         Beacon Hill
# 4            North End 2018-11-28 17:32:07   41.30         Beacon Hill
# ...                                    ...     ...                 ...
# 2614  Haymarket Square 2018-11-26 06:29:03   43.97  Financial District
# 2615  Haymarket Square 2018-11-26 06:29:03   43.97  Financial District
# 2616  Haymarket Square 2018-11-26 06:29:03   43.97  Financial District
# 2617          West End 2018-11-26 06:29:03   40.60    Haymarket Square
# 2618          West End 2018-11-26 06:29:03   40.60    Haymarket Square
#
#       clouds_x  rain_x  temp_y        location_y  clouds_y  rain_y  \
# 0         0.85     NaN   41.61     South Station      0.85     NaN
# 1         0.85     NaN   41.40         North End      0.85     NaN
# 2         0.85     NaN   41.40         North End      0.85     NaN
# 3         0.85     NaN   41.40         North End      0.85     NaN
# 4         0.85     NaN   41.40         North End      0.85     NaN
# ...        ...     ...     ...               ...       ...     ...
# 2614      1.00     NaN   40.60  Haymarket Square      1.00     NaN
# 2615      1.00     NaN   40.60  Haymarket Square      1.00     NaN
# 2616      1.00     NaN   40.60  Haymarket Square      1.00     NaN
# 2617      1.00     NaN   40.48          West End      1.00     NaN
# 2618      1.00     NaN   40.48          West End      1.00     NaN
#
#                                   merged_y
# 0        South Station 2018-11-28 17:32:07
# 1            North End 2018-11-28 17:32:07
# 2            North End 2018-11-28 17:32:07
# 3            North End 2018-11-28 17:32:07
# 4            North End 2018-11-28 17:32:07
# ...                                    ...
# 2614  Haymarket Square 2018-11-26 06:29:03
# 2615  Haymarket Square 2018-11-26 06:29:03
# 2616  Haymarket Square 2018-11-26 06:29:03
# 2617          West End 2018-11-26 06:29:03
# 2618          West End 2018-11-26 06:29:03
#
# [2619 rows x 19 columns]

# %%
merged_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2619 entries, 0 to 2618
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   distance          2619 non-null   float64
#  1   cab_type          2619 non-null   object
#  2   destination       2619 non-null   object
#  3   source            2619 non-null   object
#  4   price             2395 non-null   float64
#  5   surge_multiplier  2619 non-null   float64
#  6   id                2619 non-null   object
#  7   name              2619 non-null   object
#  8   merged_x          2619 non-null   object
#  9   dest_merged       2619 non-null   object
#  10  temp_x            2619 non-null   float64
#  11  location_x        2619 non-null   object
#  12  clouds_x          2619 non-null   float64
#  13  rain_x            263 non-null    float64
#  14  temp_y            2619 non-null   float64
#  15  location_y        2619 non-null   object
#  16  clouds_y          2619 non-null   float64
#  17  rain_y            242 non-null    float64
#  18  merged_y          2619 non-null   object
# dtypes: float64(9), object(10)
# memory usage: 409.2+ KB

# %%
merged_data2.drop(['id','merged_x','merged_y','dest_merged','location_x','location_y'],axis=1, inplace=True)
merged_data2.head()
# Out:
#    distance cab_type    destination            source  price  \
# 0      0.55     Uber  South Station  Theatre District    7.0
# 1      1.57     Uber      North End  Theatre District   18.0
# 2      1.75     Lyft      North End       Beacon Hill   26.0
# 3      2.21     Uber      North End       Beacon Hill   18.5
# 4      2.21     Uber      North End       Beacon Hill    8.5
#
#    surge_multiplier          name  temp_x  clouds_x  rain_x  temp_y  clouds_y  \
# 0               1.0         UberX   41.47      0.85     NaN   41.61      0.85
# 1               1.0         Black   41.47      0.85     NaN   41.40      0.85
# 2               1.0  Lux Black XL   41.30      0.85     NaN   41.40      0.85
# 3               1.0         Black   41.30      0.85     NaN   41.40      0.85
# 4               1.0         UberX   41.30      0.85     NaN   41.40      0.85
#
#    rain_y
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
final_df = merged_data2.rename(columns={'temp_x':'source_temp', 'clouds_x':'source_clouds', 'rain_x':'source_rain', 'temp_y':'dest_temp', 'clouds_y':'dest_clouds', 'rain_y':'dest_rain'})
final_df.head()
# Out:
#    distance cab_type    destination            source  price  \
# 0      0.55     Uber  South Station  Theatre District    7.0
# 1      1.57     Uber      North End  Theatre District   18.0
# 2      1.75     Lyft      North End       Beacon Hill   26.0
# 3      2.21     Uber      North End       Beacon Hill   18.5
# 4      2.21     Uber      North End       Beacon Hill    8.5
#
#    surge_multiplier          name  source_temp  source_clouds  source_rain  \
# 0               1.0         UberX        41.47           0.85          NaN
# 1               1.0         Black        41.47           0.85          NaN
# 2               1.0  Lux Black XL        41.30           0.85          NaN
# 3               1.0         Black        41.30           0.85          NaN
# 4               1.0         UberX        41.30           0.85          NaN
#
#    dest_temp  dest_clouds  dest_rain
# 0      41.61         0.85        NaN
# 1      41.40         0.85        NaN
# 2      41.40         0.85        NaN
# 3      41.40         0.85        NaN
# 4      41.40         0.85        NaN

# %%
final_df.isnull().any()
# Out:
# distance            False
# cab_type            False
# destination         False
# source              False
# price                True
# surge_multiplier    False
# name                False
# source_temp         False
# source_clouds       False
# source_rain          True
# dest_temp           False
# dest_clouds         False
# dest_rain            True
# dtype: bool

# %%
sns.distplot(final_df['price'].dropna())

# %%
final_df['price'].fillna(final_df['price'].median(), inplace=True)
final_df['source_rain'].fillna(0, inplace=True)
final_df['dest_rain'].fillna(0, inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2619 entries, 0 to 2618
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   distance          2619 non-null   float64
#  1   cab_type          2619 non-null   object
#  2   destination       2619 non-null   object
#  3   source            2619 non-null   object
#  4   price             2619 non-null   float64
#  5   surge_multiplier  2619 non-null   float64
#  6   name              2619 non-null   object
#  7   source_temp       2619 non-null   float64
#  8   source_clouds     2619 non-null   float64
#  9   source_rain       2619 non-null   float64
#  10  dest_temp         2619 non-null   float64
#  11  dest_clouds       2619 non-null   float64
#  12  dest_rain         2619 non-null   float64
# dtypes: float64(9), object(4)
# memory usage: 286.5+ KB

# %%
#Checking outliers
sns.boxplot(final_df['price'])

# %%
sns.boxplot(final_df['distance'])

# %%
sns.boxplot(final_df['surge_multiplier'])

# %%
final_df.head()
# Out:
#    distance cab_type    destination            source  price  \
# 0      0.55     Uber  South Station  Theatre District    7.0
# 1      1.57     Uber      North End  Theatre District   18.0
# 2      1.75     Lyft      North End       Beacon Hill   26.0
# 3      2.21     Uber      North End       Beacon Hill   18.5
# 4      2.21     Uber      North End       Beacon Hill    8.5
#
#    surge_multiplier          name  source_temp  source_clouds  source_rain  \
# 0               1.0         UberX        41.47           0.85          0.0
# 1               1.0         Black        41.47           0.85          0.0
# 2               1.0  Lux Black XL        41.30           0.85          0.0
# 3               1.0         Black        41.30           0.85          0.0
# 4               1.0         UberX        41.30           0.85          0.0
#
#    dest_temp  dest_clouds  dest_rain
# 0      41.61         0.85        0.0
# 1      41.40         0.85        0.0
# 2      41.40         0.85        0.0
# 3      41.40         0.85        0.0
# 4      41.40         0.85        0.0

# %%
final_df = final_df[['distance', 'cab_type', 'name','surge_multiplier','source', 'destination', 'source_temp', 'source_clouds', 'source_rain', 'dest_temp', 'dest_clouds', 'dest_rain','price' ]]
final_df
# Out:
#       distance cab_type          name  surge_multiplier              source  \
# 0         0.55     Uber         UberX               1.0    Theatre District
# 1         1.57     Uber         Black               1.0    Theatre District
# 2         1.75     Lyft  Lux Black XL               1.0         Beacon Hill
# 3         2.21     Uber         Black               1.0         Beacon Hill
# 4         2.21     Uber         UberX               1.0         Beacon Hill
# ...        ...      ...           ...               ...                 ...
# 2614      1.18     Lyft           Lux               1.0  Financial District
# 2615      1.18     Lyft  Lux Black XL               1.0  Financial District
# 2616      1.18     Lyft       Lyft XL               1.0  Financial District
# 2617      0.64     Lyft  Lux Black XL               1.0    Haymarket Square
# 2618      0.64     Lyft     Lux Black               1.0    Haymarket Square
#
#            destination  source_temp  source_clouds  source_rain  dest_temp  \
# 0        South Station        41.47           0.85          0.0      41.61
# 1            North End        41.47           0.85          0.0      41.40
# 2            North End        41.30           0.85          0.0      41.40
# 3            North End        41.30           0.85          0.0      41.40
# 4            North End        41.30           0.85          0.0      41.40
# ...                ...          ...            ...          ...        ...
# 2614  Haymarket Square        43.97           1.00          0.0      40.60
# 2615  Haymarket Square        43.97           1.00          0.0      40.60
# 2616  Haymarket Square        43.97           1.00          0.0      40.60
# 2617          West End        40.60           1.00          0.0      40.48
# 2618          West End        40.60           1.00          0.0      40.48
#
#       dest_clouds  dest_rain  price
# 0            0.85        0.0    7.0
# 1            0.85        0.0   18.0
# 2            0.85        0.0   26.0
# 3            0.85        0.0   18.5
# 4            0.85        0.0    8.5
# ...           ...        ...    ...
# 2614         1.00        0.0   13.5
# 2615         1.00        0.0   27.5
# 2616         1.00        0.0   10.5
# 2617         1.00        0.0   27.5
# 2618         1.00        0.0   16.5
#
# [2619 rows x 13 columns]

# %%
#Removing outliers based on price
z = np.abs(stats.zscore(final_df['price']))

# %%
final_df['z'] = z 
final_df
# Out:
#       distance cab_type          name  surge_multiplier              source  \
# 0         0.55     Uber         UberX               1.0    Theatre District
# 1         1.57     Uber         Black               1.0    Theatre District
# 2         1.75     Lyft  Lux Black XL               1.0         Beacon Hill
# 3         2.21     Uber         Black               1.0         Beacon Hill
# 4         2.21     Uber         UberX               1.0         Beacon Hill
# ...        ...      ...           ...               ...                 ...
# 2614      1.18     Lyft           Lux               1.0  Financial District
# 2615      1.18     Lyft  Lux Black XL               1.0  Financial District
# 2616      1.18     Lyft       Lyft XL               1.0  Financial District
# 2617      0.64     Lyft  Lux Black XL               1.0    Haymarket Square
# 2618      0.64     Lyft     Lux Black               1.0    Haymarket Square
#
#            destination  source_temp  source_clouds  source_rain  dest_temp  \
# 0        South Station        41.47           0.85          0.0      41.61
# 1            North End        41.47           0.85          0.0      41.40
# 2            North End        41.30           0.85          0.0      41.40
# 3            North End        41.30           0.85          0.0      41.40
# 4            North End        41.30           0.85          0.0      41.40
# ...                ...          ...            ...          ...        ...
# 2614  Haymarket Square        43.97           1.00          0.0      40.60
# 2615  Haymarket Square        43.97           1.00          0.0      40.60
# 2616  Haymarket Square        43.97           1.00          0.0      40.60
# 2617          West End        40.60           1.00          0.0      40.48
# 2618          West End        40.60           1.00          0.0      40.48
#
#       dest_clouds  dest_rain  price         z
# 0            0.85        0.0    7.0  1.034978
# 1            0.85        0.0   18.0  0.181632
# 2            0.85        0.0   26.0  1.066439
# 3            0.85        0.0   18.5  0.236933
# 4            0.85        0.0    8.5  0.869076
# ...           ...        ...    ...       ...
# 2614         1.00        0.0   13.5  0.316072
# 2615         1.00        0.0   27.5  1.232341
# 2616         1.00        0.0   10.5  0.647875
# 2617         1.00        0.0   27.5  1.232341
# 2618         1.00        0.0   16.5  0.015731
#
# [2619 rows x 14 columns]

# %%
final_df = final_df[final_df.z<=3]
final_df.drop(['z'], axis=1, inplace=True)
final_df
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       distance cab_type          name  surge_multiplier              source  \
# 0         0.55     Uber         UberX               1.0    Theatre District
# 1         1.57     Uber         Black               1.0    Theatre District
# 2         1.75     Lyft  Lux Black XL               1.0         Beacon Hill
# 3         2.21     Uber         Black               1.0         Beacon Hill
# 4         2.21     Uber         UberX               1.0         Beacon Hill
# ...        ...      ...           ...               ...                 ...
# 2614      1.18     Lyft           Lux               1.0  Financial District
# 2615      1.18     Lyft  Lux Black XL               1.0  Financial District
# 2616      1.18     Lyft       Lyft XL               1.0  Financial District
# 2617      0.64     Lyft  Lux Black XL               1.0    Haymarket Square
# 2618      0.64     Lyft     Lux Black               1.0    Haymarket Square
#
#            destination  source_temp  source_clouds  source_rain  dest_temp  \
# 0        South Station        41.47           0.85          0.0      41.61
# 1            North End        41.47           0.85          0.0      41.40
# 2            North End        41.30           0.85          0.0      41.40
# 3            North End        41.30           0.85          0.0      41.40
# 4            North End        41.30           0.85          0.0      41.40
# ...                ...          ...            ...          ...        ...
# 2614  Haymarket Square        43.97           1.00          0.0      40.60
# 2615  Haymarket Square        43.97           1.00          0.0      40.60
# 2616  Haymarket Square        43.97           1.00          0.0      40.60
# 2617          West End        40.60           1.00          0.0      40.48
# 2618          West End        40.60           1.00          0.0      40.48
#
#       dest_clouds  dest_rain  price
# 0            0.85        0.0    7.0
# 1            0.85        0.0   18.0
# 2            0.85        0.0   26.0
# 3            0.85        0.0   18.5
# 4            0.85        0.0    8.5
# ...           ...        ...    ...
# 2614         1.00        0.0   13.5
# 2615         1.00        0.0   27.5
# 2616         1.00        0.0   10.5
# 2617         1.00        0.0   27.5
# 2618         1.00        0.0   16.5
#
# [2595 rows x 13 columns]

# %%
#Splitting into dependent and independent variables
x = final_df.iloc[:,0:12].values
x
# Out:
# array([[0.55, 'Uber', 'UberX', ..., 41.61, 0.85, 0.0],
#        [1.57, 'Uber', 'Black', ..., 41.4, 0.85, 0.0],
#        [1.75, 'Lyft', 'Lux Black XL', ..., 41.4, 0.85, 0.0],
#        ...,
#        [1.18, 'Lyft', 'Lyft XL', ..., 40.6, 1.0, 0.0],
#        [0.64, 'Lyft', 'Lux Black XL', ..., 40.48, 1.0, 0.0],
#        [0.64, 'Lyft', 'Lux Black', ..., 40.48, 1.0, 0.0]], dtype=object)

# %%
x.shape
# Out:
# (2595, 12)

# %%
y = final_df.iloc[:,-1].values
y
# Out:
# array([ 7. , 18. , 26. , ..., 10.5, 27.5, 16.5])

# %%
ct = ColumnTransformer([('oh',OneHotEncoder(drop='first'),[1,2,4,5])],remainder='passthrough')
x = ct.fit_transform(x)

# %%
import joblib
joblib.dump(ct,'onehot.save')
# Out:
# ['onehot.save']

# %%
x.shape
# Out:
# (2595, 43)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (2076, 43)

# %%
x_test.shape
# Out:
# (519, 43)

# %%
y_train.shape
# Out:
# (2076,)

# %%
y_test.shape
# Out:
# (519,)

# %% [markdown]
# # Model Building

# %%
rand = RandomForestRegressor(n_estimators=20, max_depth=17, random_state=10)
rand.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=17, n_estimators=20, random_state=10)

# %%
#!pip install ibm_watson_machine_learning

# %%
from ibm_watson_machine_learning import APIClient

wml_credentials = {
    "url": "https://us-south.ml.cloud.ibm.com",
    "apikey": "_H3nxJFrwLvNB51OFdXzqCPJ9_k_tQIHGqQwqUWTVwSS"
}

client = APIClient(wml_credentials)

# %%
def guid_from_space_name(client, space_name):
    space = client.spaces.get_details()
    return(next(item for item in space['resources'] if item['entity']['name'] == space_name)['metadata']['id'])

# %%
space_uid = guid_from_space_name(client, 'models')
print("Space UID = " + space_uid)
# Out:
# Space UID = 2c4bbfa9-e253-4e83-bc1c-2830e228e4f2

# %%
client.set.default_space(space_uid)
# Out:
# 'SUCCESS'

# %%
client.software_specifications.list()
# Out:
# -----------------------------  ------------------------------------  ----
# NAME                           ASSET_ID                              TYPE
# default_py3.6                  0062b8c9-8b7d-44a0-a9b9-46c416adcbd9  base
# pytorch-onnx_1.3-py3.7-edt     069ea134-3346-5748-b513-49120e15d288  base
# scikit-learn_0.20-py3.6        09c5a1d0-9c1e-4473-a344-eb7b665ff687  base
# spark-mllib_3.0-scala_2.12     09f4cff0-90a7-5899-b9ed-1ef348aebdee  base
# ai-function_0.1-py3.6          0cdb0f1e-5376-4f4d-92dd-da3b69aa9bda  base
# shiny-r3.6                     0e6e79df-875e-4f24-8ae9-62dcc2148306  base
# tensorflow_2.4-py3.7-horovod   1092590a-307d-563d-9b62-4eb7d64b3f22  base
# pytorch_1.1-py3.6              10ac12d6-6b30-4ccd-8392-3e922c096a92  base
# tensorflow_1.15-py3.6-ddl      111e41b3-de2d-5422-a4d6-bf776828c4b7  base
# scikit-learn_0.22-py3.6        154010fa-5b3b-4ac1-82af-4d5ee5abbc85  base
# default_r3.6                   1b70aec3-ab34-4b87-8aa0-a4a3c8296a36  base
# pytorch-onnx_1.3-py3.6         1bc6029a-cc97-56da-b8e0-39c3880dbbe7  base
# tensorflow_2.1-py3.6           1eb25b84-d6ed-5dde-b6a5-3fbdf1665666  base
# tensorflow_2.4-py3.8-horovod   217c16f6-178f-56bf-824a-b19f20564c49  base
# do_py3.8                       295addb5-9ef9-547e-9bf4-92ae3563e720  base
# autoai-ts_3.8-py3.8            2aa0c932-798f-5ae9-abd6-15e0c2402fb5  base
# tensorflow_1.15-py3.6          2b73a275-7cbf-420b-a912-eae7f436e0bc  base
# pytorch_1.2-py3.6              2c8ef57d-2687-4b7d-acce-01f94976dac1  base
# spark-mllib_2.3                2e51f700-bca0-4b0d-88dc-5c6791338875  base
# pytorch-onnx_1.1-py3.6-edt     32983cea-3f32-4400-8965-dde874a8d67e  base
# spark-mllib_3.0-py37           36507ebe-8770-55ba-ab2a-eafe787600e9  base
# spark-mllib_2.4                390d21f8-e58b-4fac-9c55-d7ceda621326  base
# xgboost_0.82-py3.6             39e31acd-5f30-41dc-ae44-60233c80306e  base
# pytorch-onnx_1.2-py3.6-edt     40589d0e-7019-4e28-8daa-fb03b6f4fe12  base
# autoai-obm_3.0                 42b92e18-d9ab-567f-988a-4240ba1ed5f7  base
# spark-mllib_2.4-r_3.6          49403dff-92e9-4c87-a3d7-a42d0021c095  base
# xgboost_0.90-py3.6             4ff8d6c2-1343-4c18-85e1-689c965304d3  base
# pytorch-onnx_1.1-py3.6         50f95b2a-bc16-43bb-bc94-b0bed208c60b  base
# spark-mllib_2.4-scala_2.11     55a70f99-7320-4be5-9fb9-9edb5a443af5  base
# autoai-obm_2.0                 5c2e37fa-80b8-5e77-840f-d912469614ee  base
# spss-modeler_18.1              5c3cad7e-507f-4b2a-a9a3-ab53a21dee8b  base
# cuda-py3.8                     5d3232bf-c86b-5df4-a2cd-7bb870a1cd4e  base
# autoai-kb_3.1-py3.7            632d4b22-10aa-5180-88f0-f52dfb6444d7  base
# pytorch-onnx_1.7-py3.8         634d3cdc-b562-5bf9-a2d4-ea90a478456b  base
# spark-mllib_2.3-r_3.6          6586b9e3-ccd6-4f92-900f-0f8cb2bd6f0c  base
# tensorflow_2.4-py3.7           65e171d7-72d1-55d9-8ebb-f813d620c9bb  base
# spss-modeler_18.2              687eddc9-028a-4117-b9dd-e57b36f1efa5  base
# pytorch-onnx_1.2-py3.6         692a6a4d-2c4d-45ff-a1ed-b167ee55469a  base
# do_12.9                        75a3a4b0-6aa0-41b3-a618-48b1f56332a6  base
# spark-mllib_2.3-scala_2.11     7963efe5-bbec-417e-92cf-0574e21b4e8d  base
# spark-mllib_2.4-py37           7abc992b-b685-532b-a122-a396a3cdbaab  base
# caffe_1.0-py3.6                7bb3dbe2-da6e-4145-918d-b6d84aa93b6b  base
# pytorch-onnx_1.7-py3.7         812c6631-42b7-5613-982b-02098e6c909c  base
# cuda-py3.6                     82c79ece-4d12-40e6-8787-a7b9e0f62770  base
# tensorflow_1.15-py3.6-horovod  8964680e-d5e4-5bb8-919b-8342c6c0dfd8  base
# hybrid_0.1                     8c1a58c6-62b5-4dc4-987a-df751c2756b6  base
# pytorch-onnx_1.3-py3.7         8d5d8a87-a912-54cf-81ec-3914adaa988d  base
# caffe-ibm_1.0-py3.6            8d863266-7927-4d1e-97d7-56a7f4c0a19b  base
# spss-modeler_17.1              902d0051-84bd-4af6-ab6b-8f6aa6fdeabb  base
# do_12.10                       9100fd72-8159-4eb9-8a0b-a87e12eefa36  base
# -----------------------------  ------------------------------------  ----
# Note: Only first 50 records were displayed. To display more use 'limit' parameter.

# %%
software_spec_uid = client.software_specifications.get_uid_by_name("default_py3.7")
software_spec_uid
# Out:
# 'e4429883-c883-42b6-87a8-f419d64088cd'

# %%
model_details = client.repository.store_model(model=rand,meta_props={
    client.repository.ModelMetaNames.NAME: 'Cab Price Prediction',
    client.repository.ModelMetaNames.TYPE: 'scikit-learn_0.23',
    client.repository.ModelMetaNames.SOFTWARE_SPEC_UID: software_spec_uid
})

model_id = client.repository.get_model_uid(model_details)
model_id
# Out:
# '0a10f046-b37f-4501-88b2-8828a324d1bd'

# %%
y_pred = rand.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9535695714561604

# %%
rand.score(x_train,y_train)
# Out:
# 0.9912930223069562

# %%
joblib.dump(rand,'model.save')
# Out:
# ['model.save']

# %% [markdown]
# Model has been saved

# %%
final_df.iloc[0:1,:].values
# Out:
# array([[0.55, 'Uber', 'UberX', 1.0, 'Theatre District', 'South Station',
#         41.47, 0.85, 0.0, 41.61, 0.85, 0.0, 7.0]], dtype=object)

# %%
#Demonstration of joblib 
trans = joblib.load('onehot.save')
x_dym = trans.transform([[0.55, 'Uber', 'UberX', 1.0, 'Theatre District', 'South Station', 41.47, 0.85, 0.0, 41.61, 0.85, 0.0]])
x_dym.shape
# Out:
# (1, 43)

# %%
load_model = joblib.load('model.save')
load_model.predict(x_dym)
# Out:
# array([7.175])
